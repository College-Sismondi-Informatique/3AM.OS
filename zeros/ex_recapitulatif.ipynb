# %% [markdown]
# # Exercice de révision sur la résolution d'équations non linéaires
#
# On cherche à comparer les méthodes de Dichotomie, de Newton et du Point fixe pour déterminer le zéro de la fonction $f$ suivante :
# $$f(x)=\frac{10x-2\sin(x)-5}{10} $$
#
#
# 1) Tracer le graphique de $f$ dans l'intervalle $[\textstyle\frac{1}{2};1]$ et vérifier que $f$ possède un zéro dans cet intervalle.
#
# 2) Utiliser la méthode de bissection sur l'intervalle utilisé en 1. afin d'estimer le zéro avec un tolérence de $10^{-7}$ et donner le nombre d'étapes nécessaires.
#
# 3) Utiliser la méthode de Newton (prendre $x_0=1$) afin d'estimer le zéro avec un tolérence de $10^{-7}$ et donner le nombre d'étapes nécessaires.
#
# 4) Méthode du point fixe
#
#      a) Montrer que $h(x)=f(x)+x$ n'est pas un bon choix pour la fonction $h$ afin d'appliquer la méthode du point fixe.
#
#      b) Montrer que $f(x)=0 \Leftrightarrow 0,2\sin(x)+0,5=x$ et montrer que la fonction définie par $g(x)=0,2\sin(x)+0,5$ vérifie toutes les hypothèses du théorème de convergence du point fixe sur l'intervalle $[\textstyle\frac{1}{2};1]$.
#
#      c) Initier la méthode du point fixe sur cet intervalle (prendre $x_0=1$) et donner le nombre d'étapes nécessaires pour obtenir une précision d'ordre $10^{-7}$.

# %%
# tracer le graphique de

# %% [raw]
# Le zéro est situé autour du point x=...

# %%
# méthode de la bissection

# %% [raw]
# En utilisant la méthode de la bissection avec une tolérence 0.00000001, on obtient x=... comme zéro après ... étapes.

# %%
# méthode de Newton

# %% [raw]
# En utilisant la méthode de Newton avec une tolérence 0.00000001, on obtient x=... comme zéro après ... étapes.

# %%
# Afficher le graphique de h et h' et discuter de la
# convergence vers le point fixe

# %% [raw]
# La méthode converge/diverge vers le point fixe car ...

# %%
# méthode du point fixe

# %% [raw]
# En utilisant la méthode du point fixe avec une tolérence 0.00000001, on obtient x=... comme zéro après ... étapes.
